# %% [markdown]
# # TP Optimisation II:  A simple neural network
#
# ### Nom(s): Hammi
# ### Prénom(s): Kamal
# ### Groupe: B2

# %% [markdown]
# ## Useful packages

# %%
import numpy as np
import random
import math
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %% [markdown]
# ## Loading of the train and test data

# %%
#
# Load train data
#
Xtrain = np.load('train-images.npy')
Xtrain = np.array([x.ravel()/255 for x in Xtrain])
Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],1)
Ytrain = np.load('train-labels.npy')
targets_train = []

#
# Convert digits to 10x1 vectors
#
for lab in Ytrain:
    v      = np.zeros((10,1))
    v[lab] = 1
    targets_train+=[np.array(v)]

#
# Load test data
#
Xtest        = np.load('t10k-images.npy')
Xtest        = np.array([x.ravel()/255 for x in Xtest])
Xtest        = Xtest.reshape(Xtest.shape[0],Xtest.shape[1],1)
Ytest        = np.load('t10k-labels.npy')
targets_test = []

#
# Convert digits to 10x1 vectors
#
for lab in Ytest:
    v = np.zeros((10,1))
    v[lab]=1
    targets_test+=[np.array(v)]
#
# Outputs
#
print('There are ',Xtrain.shape[0],'images in the train set')
print('There are ',Xtest.shape[0],'images in the test set')
# Out:
# There are  60000 images in the train set
# There are  10000 images in the test set

# %% [markdown]
# ## Definition of the activation function
#
#  The activation function defines the output of a node given a set of inputs. We use the <a href="https://en.wikipedia.org/wiki/Softmax_function">softmax</a> function defined by
#
#  $$\sigma_{\alpha} : \mathbb{R}^p\rightarrow [0,1]^p, \quad \mbox{ s.t.} \quad[\sigma_{\alpha}(x)]_i=\frac{e^{x_i+\alpha_i}}{\displaystyle{\sum_{j=1}^{p}e^{x_j+\alpha_j}}}\quad \forall i=1:p. $$

# %%
#
# Nonlinear activation function
#
def softmax(x,alpha):
    """
    Softmax unit activation function 
    x    : Numpy array
    alpha: scalar
    """ 
    #
    # TO DO
    #
    n = len(x)
    value = np.zeros([n,1])
    for i in range(n):
        value[i] = math.exp(x[i]+alpha)
    
    return 1/np.sum(value)*value

# %%
#
# Example of a plot of the activation function
#
t     = np.arange(-5,5,0.1)
alpha = 0. #np.arange(-50,50,1)
plt.figure(figsize=(10,10))
plt.plot(t,softmax(t,alpha))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Definition of a simple neural network
#
# We use a one-layer fully-connected neural network with the <a href="https://en.wikipedia.org/wiki/Softmax_function">softmax</a> activation function.

# %%
def NN(x,W):
    """
    # One-layer fully connected neural network
    # x: image, i.e. 784x1 vector (28x28)
    # W: weight matrices of shape 10x784   
    """
    #
    # TO DO: return pred (predicted probabilities) 
    #
    pred = softmax(np.dot(W,x),alpha)
    return pred

# %% [markdown]
# ## Definition of the loss function
#
# The loss function is the <a href="https://en.wikipedia.org/wiki/Cross_entropy">cross-entropy</a> defined by
#
# $$J(W)=-\sum_{i=1}^N p_i \log(q_i(W)),$$ where $N$ is the number of classes, $(p_i)_{i=1:N}$ are the probabilities of  a data from the training set to belong to a class (0 or 1 because the labels are known), and $(q_i(W))_{i=1:N}$ are the predicted probabilities from the model
#
# $$\forall i=1:N, \quad q_i(W)=[\sigma_{\alpha}(Wx)]_i.$$

# %%
#
# Loss function = Cross-entropy
#
def cross_entropy(pred,target,x):
    """
    pred:   predicted probabilities (q(W))
    target: probabilities (p)
    x:      image 
    """ 
    #
    # TO DO: return ce (cross_entropy)
    #
    ce = -np.dot(np.transpose(target),np.log(pred))
    #
    # gradient of the cross-entropy
    #
    u    =  np.ones((pred.shape[0],1))
    g    = (-u.T.dot(target)*(pred.dot(x.T))+target*x.T)
    grad = -g.reshape(x.shape[0]*target.shape[0],1)
    
    return ce,grad
#
# Main function 
#
def f(W,x,target):
    """
    W:      weights
    target: probabilities (p)
    x:      image
    """
    #
    # TO DO: return ce, grad, pred (cross_entropy, gradient, predicted probabilities)
    #
    pred = NN(x,W)
    ce,grad = cross_entropy(pred,target,x)
    return ce,grad,pred

# %%
#
# Test information on the gradient with calls of f
#

# Define weight matrices
W      = np.random.rand(10,Xtrain.shape[1])
eps    = 1e-8
d      = np.random.rand(10,Xtrain.shape[1])
Wtilde = W+eps*d

# Retrieve the information on the gradients
res    = (f(Wtilde,Xtrain[0],targets_train[0])[0]-f(W,Xtrain[0],targets_train[0])[0])/eps
print(res)

g      = f(W,Xtrain[0],targets_train[0])[1]
print(g.T.dot(d.reshape(7840,1)))
# Out:
# [[1.72904215]]
# [[1.7290411]]

# %% [markdown]
# ## Generating batches

# %%
#
# Function to create batches of samples to be used later in the training phase
#
def create_batches(x,bs):
    """
    x : set to be considered (array)
    bs: batch size (scalar)
    """
    batches = []
    ind     = np.arange(x.shape[0])
    random.shuffle(ind)
    nbatch  = ind.shape[0]//bs
    rest    = ind.shape[0]%bs
    
    for n in range(nbatch):
        batches +=[ind[bs*n:bs*(n+1)]]
    
    # Put the remaining elements in a last batch
    if rest !=0:        
        batches += [ind[-rest:]]
        
    return batches

# %% [markdown]
# ## Training of the neural network

# %%
history    = {}
eta        = 1e-5 # learning rate
momentum   = 0.   # momemtum factor
N_EPOCHS   = 10  
BatchSizes = [10000,1024,256] # try different batch sizes for the analysis

for bs in BatchSizes:
    #
    # Sensitivity to the batch size to be investigated in the analysis
    #
    print('batch size=',bs)
    
    history[bs]={'train loss':[],'train acc':[],'test loss':[0], 'test acc':[0]}
    
    # Initialization of the weights
    w = np.random.rand(10,Xtrain.shape[1])
    
    for n in range(N_EPOCHS):
        # Minimization of the loss function
        
        Batches=create_batches(Xtrain,bs)
        for batch in Batches:
            # Loop on the batches
            #
            # TO DO
            somme_grad = 0
            ce_train = 0
            ce_test = 0
            
            train_acc = 0
            test_acc = 0
            
            for indx in batch:
                x = Xtrain[indx]
                target = targets_train[indx] 
                
                ce,grad,pred = f(w,x,target)
                somme_grad += grad
                ce_train+=ce
                
                prediction = np.where(pred == np.max(pred))[0]
                true = np.where(target == 1)[0]
                
                if prediction==true:
                    train_acc +=1
                    
            history[bs]['train acc'] += [train_acc/len(batch)]
            history[bs]['train loss'] += [ce_train[0][0]/len(batch)]

            somme_grad = somme_grad.reshape(w.shape[0],w.shape[1])
            w = w-eta*somme_grad
                
        # Test accuracy at the end of each epoch  
        #
        # TO DO
        #
        for ind_test in range(len(Xtest)):
            x = Xtest[ind_test]
            lab = targets_test[ind_test]
            ce,_,pred = f(w,x,lab)
            ce_test += ce
            prediction = np.where(pred == np.max(pred))[0]
            true = np.where(lab == 1)[0]
                
            if prediction==true:
                test_acc +=1
                    
        history[bs]['test acc'] += [test_acc/Xtest.shape[0]]
        history[bs]['test loss'] += [ce_test[0][0]/Xtest.shape[0]]
        
        print('Epoch number :', n+1,'test accuracy:',history[bs]['test acc'][n+1],'test loss',history[bs]['test loss'][n+1])
        

    print('\n')
# Out:
# batch size= 10000
# Epoch number : 1 test accuracy: 0.1551 test loss 3.3280914619300397
# Epoch number : 2 test accuracy: 0.2244 test loss 2.7370290182585912
# Epoch number : 3 test accuracy: 0.3056 test loss 2.3326111393004996
# Epoch number : 4 test accuracy: 0.3741 test loss 2.0269115705951966
# Epoch number : 5 test accuracy: 0.434 test loss 1.7929852780622995
# Epoch number : 6 test accuracy: 0.4872 test loss 1.6115003475744598
# Epoch number : 7 test accuracy: 0.5252 test loss 1.467936074014823
# Epoch number : 8 test accuracy: 0.5617 test loss 1.3524481199838858
# Epoch number : 9 test accuracy: 0.5908 test loss 1.2580054888986687
# Epoch number : 10 test accuracy: 0.6181 test loss 1.1796454432305779
#
#
# batch size= 1024
# Epoch number : 1 test accuracy: 0.148 test loss 3.326017027537032
# Epoch number : 2 test accuracy: 0.2241 test loss 2.690899840805105
# Epoch number : 3 test accuracy: 0.3088 test loss 2.237862523272502
# Epoch number : 4 test accuracy: 0.3897 test loss 1.9093847803077122
# Epoch number : 5 test accuracy: 0.4619 test loss 1.6717800632783775
# Epoch number : 6 test accuracy: 0.5177 test loss 1.4965438866594436
# Epoch number : 7 test accuracy: 0.5599 test loss 1.3634248957067636
# Epoch number : 8 test accuracy: 0.594 test loss 1.2593553526536694
# Epoch number : 9 test accuracy: 0.6208 test loss 1.1759140898546714
# Epoch number : 10 test accuracy: 0.6451 test loss 1.1075981602158493
#
#
# batch size= 256
# Epoch number : 1 test accuracy: 0.1158 test loss 3.5352596681967725
# Epoch number : 2 test accuracy: 0.1834 test loss 2.8243242513926363
# Epoch number : 3 test accuracy: 0.2697 test loss 2.3557999845693636
# Epoch number : 4 test accuracy: 0.3647 test loss 2.0143900692118355
# Epoch number : 5 test accuracy: 0.447 test loss 1.762859686568654
# Epoch number : 6 test accuracy: 0.5027 test loss 1.573913777529737
# Epoch number : 7 test accuracy: 0.5431 test loss 1.4283974428586348
# Epoch number : 8 test accuracy: 0.5788 test loss 1.313134265816349
# Epoch number : 9 test accuracy: 0.6062 test loss 1.219995906155473
# Epoch number : 10 test accuracy: 0.6296 test loss 1.1431139827397618

# %% [markdown]
# ## Plots of the evolution of the loss function

# %%
for bs in BatchSizes:
       
    n_batch = Xtrain.shape[0]//bs     
    if Xtrain.shape[0]%bs!=0:
        n_batch+=1
        
    E  = [n_batch*n for n in np.arange(N_EPOCHS+1)]
    Ep = [str(n) for n in np.arange(N_EPOCHS+1)]
    
    plt.figure(figsize=(7,7))
    plt.plot(history[bs]['train loss'],label = 'training loss')
    plt.plot(E[1:],history[bs]['test loss'][1:],linewidth=2.5,label = 'test loss')
    plt.xticks(E,Ep)
    plt.xlabel('Epochs')
    plt.ylabel('Loss Value')
    #plt.ylim([0,np.max(history[bs]['test loss'])+2])
    plt.grid(True)
    plt.legend()
    plt.title(f'model trained with a Batch size of {bs} samples and learning rate of {eta}')
    plt.show()

# %% [markdown]
# ## Plots of the evolution of the accuracy

# %%
for bs in BatchSizes:
    print(bs)   
    n_batch = Xtrain.shape[0]//bs     
    if Xtrain.shape[0]%bs!=0:
        n_batch+=1
        
    print(n_batch)
    E=[n_batch*n for n in np.arange(N_EPOCHS+1)]
    Ep = [str(n) for n in np.arange(N_EPOCHS+1)]
    
    plt.figure(figsize=(7,7))
    plt.plot(history[bs]['train acc'] ,label  = 'training acuracy')
    plt.plot(E[1:],history[bs]['test acc'][1:],linewidth=2.5,label = 'test acuracy')
    plt.xticks(E,Ep)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.title(f'model trained with a Batch size of {bs} samples and learning rate of {eta}')
    plt.ylim([0,1])
    plt.legend()
    
    plt.show()
# Out:
# 10000
# 6
# 1024
# 59
# 256
# 235

# %% [markdown]
# ## Analysis of the results
#
# Please provide your comments on the sensitivity of the results to the parameters involved in the learning process (batch size, learning rate, momentum).

# %% [markdown]
# ### Your comments:
# We note that the loss decrease and the accuracy increase which means that the results are corrects, and we can remark that the fluctuation of both traning loss and trainning accuracy is bigger when the batch size is bigger. But that last fact dosn't fluctuate neither test loss nor test accuracy.
